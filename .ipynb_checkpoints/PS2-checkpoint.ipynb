# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import re
import datetime
import pylab as pl
pl.style.use('fivethirtyeight')
import statsmodels.formula.api as smf
from statsmodels.graphics.api import abline_plot
import statsmodels.api as sma

# %%
census = pd.read_csv('PST01.csv')
census = census.rename(columns={'PST045202D': 'Population'})

# %%
census.columns
# Out:
# Index([u'Areaname', u'STCOU', u'Population'], dtype='object')

# %%
carbon = pd.read_csv('carbon.csv')

# %%
carbon.columns
# Out:
# Index([u'State', u'County', u'FIPS', u'Total', u'Commercial', u'Industrial',
#        u'Residential', u'Electricity Prod', u'Onroad', u'Cement', u'Aircraft',
#        u'Airborne', u'Nonroad'],
#       dtype='object')

# %%
merged = pd.merge(census, carbon, left_on='STCOU', right_on='FIPS')

# %%
merged.plot('Population', 'Total', kind='scatter', logy=True, logx=True)

# %%
merged.describe()
# Out:
#               STCOU      Population          FIPS        Total   Commercial  \
# count   3138.000000     3138.000000   3138.000000  3138.000000  3138.000000
# mean   30435.328553    91710.801147  30435.328553     0.510080     0.021177
# std    15134.945712   299313.711814  15134.945712     1.199037     0.077770
# min     1001.000000       66.000000   1001.000000     0.001961     0.000000
# 25%    19001.500000    11172.500000  19001.500000     0.047465     0.001068
# 50%    29182.000000    24911.000000  29182.000000     0.115906     0.003260
# 75%    45084.500000    62334.250000  45084.500000     0.342149     0.011559
# max    56045.000000  9717871.000000  56045.000000    21.316004     1.717594
#
#         Industrial  Residential  Electricity Prod       Onroad       Cement  \
# count  3138.000000  3138.000000       3138.000000  3138.000000  3138.000000
# mean      0.091057     0.032428          0.197242     0.127406     0.004018
# std       0.437060     0.108491          0.687677     0.325747     0.032664
# min       0.000000     0.000000          0.000000     0.000088     0.000000
# 25%       0.003498     0.003411          0.000000     0.021910     0.000000
# 50%       0.014855     0.007771          0.000000     0.048480     0.000000
# 75%       0.048551     0.020539          0.001932     0.108986     0.000000
# max       9.890448     3.251092          7.406676     9.360510     0.849118
#
#           Aircraft     Airborne      Nonroad
# count  3138.000000  3138.000000  3138.000000
# mean      0.005838     0.015271     0.015642
# std       0.025510     0.065612     0.034940
# min       0.000000     0.000000     0.000004
# 25%       0.000000     0.000000     0.003921
# 50%       0.000956     0.002411     0.007759
# 75%       0.003722     0.009374     0.013887
# max       0.979744     2.462769     0.867329

# %%
merged.sort('Population', ascending=False).head(20)
# Out:
#                 Areaname  STCOU  Population State          County   FIPS  \
# 199      Los Angeles, CA   6037     9717871    CA     Los Angeles   6037
# 605             Cook, IL  17031     5355574    IL            Cook  17031
# 2618          Harris, TX  48201     3557879    TX          Harris  48201
# 98          Maricopa, AZ   4013     3299127    AZ        Maricopa   4013
# 210           Orange, CA   6059     2917106    CA          Orange   6059
# 217        San Diego, CA   6073     2901235    CA       San Diego   6073
# 1846           Kings, NY  36047     2477380    NY           Kings  36047
# 357       Miami-Dade, FL  12086     2328122    FL      Miami-Dade  12086
# 2574          Dallas, TX  48113     2280415    TX          Dallas  48113
# 1863          Queens, NY  36081     2239457    NY          Queens  36081
# 2289  0.783171  0.000000  0.016452  0.041355  0.083777

# %%
merged[merged.STCOU==36047]
# Out:
#        Areaname  STCOU  Population State County   FIPS     Total  Commercial  \
# 1846  Kings, NY  36047     2477380    NY  Kings  36047  2.762536    0.304717
#
#       Industrial  Residential  Electricity Prod    Onroad  Cement  Aircraft  \
# 1846    0.096474     1.263711          0.365362  0.591724       0         0
#
#       Airborne   Nonroad
# 1846         0  0.140547

# %%
mod = smf.ols(formula='Total ~ Population', data = merged).fit()
print mod.summary()

merged['Population2'] = merged['Population']**2
mod = smf.ols(formula='Total ~ Population + Population2', data = merged).fit()
print mod.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Total   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.507
# Method:                 Least Squares   F-statistic:                     3224.
# Date:                Tue, 10 Nov 2015   Prob (F-statistic):               0.00
# Time:                        15:50:24   Log-Likelihood:                -3912.3
# No. Observations:                3138   AIC:                             7829.
# Df Residuals:                    3136   BIC:                             7841.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.2485      0.016     15.806      0.000         0.218     0.279
# Population  2.852e-06   5.02e-08     56.780      0.000      2.75e-06  2.95e-06
# ==============================================================================
# Omnibus:                     2905.425   Durbin-Watson:                   1.924
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           121547.527
# Skew:                           4.409   Prob(JB):                         0.00
# Kurtosis:                      32.187   Cond. No.                     3.27e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.27e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Total   R-squared:                       0.523
# Model:                            OLS   Adj. R-squared:                  0.522
# Method:                 Least Squares   F-statistic:                     1717.
# Date:                Tue, 10 Nov 2015   Prob (F-statistic):               0.00
# Time:                        15:50:24   Log-Likelihood:                -3861.3
# No. Observations:                3138   AIC:                             7729.
# Df Residuals:                    3135   BIC:                             7747.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Intercept       0.2028      0.016     12.589      0.000         0.171     0.234
# Population   3.494e-06   8.01e-08     43.628      0.000      3.34e-06  3.65e-06
# Population2  -1.34e-13   1.32e-14    -10.183      0.000      -1.6e-13 -1.08e-13
# ==============================================================================
# Omnibus:                     2906.171   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           113708.124
# Skew:                           4.442   Prob(JB):                         0.00
# Kurtosis:                      31.120   Cond. No.                     1.99e+12
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.99e+12. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
merged['PerCapita'] = merged['Total']/merged['Population']

# %%
merged.plot('Population', 'PerCapita', kind='scatter', logy=True, logx=True)

# %%
#figure, ax = pl.subplots(figsize=(16,16))
#ax.scatter(streak, cycle)

ax = merged.plot('Population', 'PerCapita', kind='scatter', logy=True, logx=True)

mod = smf.ols(formula='PerCapita ~ Population', data = merged).fit()
print mod.summary()
abline_plot(model_results=mod, ax=ax, color='red')
ax.set_title('311 Complaints (Cycle) vs Win Streak (NYM)')
#ax.set_xlabel('Win Streak')
#ax.set_ylabel('311 Complaint Cycle')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              PerCapita   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     6.835
# Date:                Tue, 10 Nov 2015   Prob (F-statistic):            0.00898
# Time:                        15:54:33   Log-Likelihood:                 27586.
# No. Observations:                3138   AIC:                        -5.517e+04
# Df Residuals:                    3136   BIC:                        -5.516e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    1.17e-05   6.87e-07     17.013      0.000      1.03e-05   1.3e-05
# Population -5.742e-12    2.2e-12     -2.614      0.009        -1e-11 -1.44e-12
# ==============================================================================
# Omnibus:                     5174.396   Durbin-Watson:                   1.879
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3533471.668
# Skew:                          10.918   Prob(JB):                         0.00
# Kurtosis:                     165.935   Cond. No.                     3.27e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.27e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
