# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import re
import datetime
import pylab as pl
pl.style.use('fivethirtyeight')
import statsmodels.formula.api as smf
from statsmodels.graphics.api import abline_plot
import statsmodels.api as sma

# %%
census = pd.read_csv('PST01.csv')
census = census.rename(columns={'PST045202D': 'Population'})

# %%
census.columns
# Out:
# Index([u'Areaname', u'STCOU', u'Population'], dtype='object')

# %%
carbon = pd.read_csv('carbon.csv')

# %%
carbon.columns
# Out:
# Index([u'State', u'County', u'FIPS', u'Total', u'Commercial', u'Industrial',
#        u'Residential', u'Electricity Prod', u'Onroad', u'Cement', u'Aircraft',
#        u'Airborne', u'Nonroad'],
#       dtype='object')

# %%
area = pd.read_csv('land.csv')

# %%
area.columns
# Out:
# Index([u'Areaname', u'STCOU', u'area'], dtype='object')

# %%
merged = pd.merge(census, area, on='STCOU')

# %%
merged = pd.merge(merged, carbon, left_on='STCOU', right_on='FIPS')

# %%
merged.columns
# Out:
# Index([u'Areaname_x', u'STCOU', u'Population', u'Areaname_y', u'area',
#        u'State', u'County', u'FIPS', u'Total', u'Commercial', u'Industrial',
#        u'Residential', u'Electricity Prod', u'Onroad', u'Cement', u'Aircraft',
#        u'Airborne', u'Nonroad'],
#       dtype='object')

# %%
# Filter out areas of 0
merged = merged[merged.area > 0]

# %%
# Total is the amount of CO2 emissions in millions of tons
# area is the number of square miles
# CO2PerSquareMile is millions of tons per square mile
merged['CO2PerSquareMile'] = merged['Total']/merged['area']

# %%
# CO2PerCapita is Millions of tons per capita
merged['CO2PerCapita'] = merged['Total']/merged['Population']

# %%
# ResCO2PerCapita is Millions of tons per capita
merged['ResCO2PerCapita'] = (merged['Total'] - merged['Onroad'])/merged['Population']

# %%
merged['ResCO2PerCapita'].describe()
# Out:
# count    3.137000e+03
# mean     9.081878e-06
# std      3.671871e-05
# min      1.800141e-07
# 25%      1.242196e-06
# 50%      1.971957e-06
# 75%      3.867465e-06
# max      7.984987e-04
# Name: ResCO2PerCapita, dtype: float64

# %%
# PopulationDensity in people per square mile
merged['PopulationDensity'] = merged['Population']/merged['area']

# %%
def basicPlots(df, plots):
    for x,y,title,xl,yl in plots:
        ax = df.plot(x, y, kind='scatter', logy=True, logx=True, figsize=(10,10))
        ax.set_title(title)
        ax.set_xlabel(xl)
        ax.set_ylabel(yl)

# %%
basicPlots(merged, [
        ('Population', 'Total', 'CO2 Emissions vs. Population by County', 'Population', 'Millions of Tons of CO2'),
        ('Population', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population by County', 'Population', 'Millions of Tons of CO2 per Square Mile'),
        ('Population', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population by County', 'Population', 'Millions of Tons of CO2 per Capita'),
        ('PopulationDensity', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population Density by County', 'Population per Square Mile', 'Millions of Tons of CO2 per Capita'),
        ('PopulationDensity', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population Density by County', 'Population per Square Mile', 'Millions of Tons of CO2 per Square Mile'),
    ])

# %%
basicPlots(merged[merged.Population > 100000], [
        ('Population', 'Total', 'CO2 Emissions vs. Population by County', 'Population', 'Millions of Tons of CO2'),
        ('Population', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population by County', 'Population', 'Millions of Tons of CO2 per Square Mile'),
        ('Population', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population by County', 'Population', 'Millions of Tons of CO2 per Capita'),
        ('PopulationDensity', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population Density by County', 'Population per Square Mile', 'Millions of Tons of CO2 per Capita'),
        ('PopulationDensity', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population Density by County', 'Population per Square Mile', 'Millions of Tons of CO2 per Square Mile'),
    ])

# %%
def runRegressions(df, plots):
    mods = []
    for x,y,title,xl,yl,ax,c in plots:
        #figure, ax = pl.subplots(figsize=(10,10))
        
        d = {
            'x': np.log2(df[x]),
            'y': np.log2(df[y]),
            'x2': np.log2(df[x])**2
        }
        
        logPop = np.log(df[c])
        min = np.min(logPop)
        max = np.max(logPop)
        
        a = -256./(min - max)
        b = 0 + -1 * min * a
        colors = logPop*a + b
        
        #a = -400./(df['Population'].min() - df['Population'].max())
        #b = 15 + -1 * df['Population'].min() * a
        #sizes = df['Population']*a + b
        
        a = 400./(max-min)
        b = 20 - min * a
        sizes = logPop*a + b
        #print sizes
        #print colors
        #sizes = -1*min + logPop*

        
        ax.scatter(d['x'], d['y'], s=sizes, cmap=pl.cm.jet, c=colors)

        mod = smf.ols(formula='y ~ x', data = d).fit()
        mods.append(mod)
        print title
        print mod.summary()
        abline_plot(model_results=mod, ax=ax, color='red', label='Regression')

        
        #mod = smf.ols(formula='y ~ x + x2', data = d).fit()
        #print mod.summary()
        #xlim = ax.get_xlim()
        #x = np.linspace(xlim[0], xlim[1],100)
        #y = mod.params[0] + x*mod.params[1] + (x**2)*mod.params[2]
        #ax.plot(x, y, label='Polynomial')
        
        #ax = df.plot(x, y, kind='scatter', logy=True, logx=True, figsize=(10,10))
        ax.set_title(title)
        ax.set_xlabel(xl)
        ax.set_ylabel(yl)
        ax.legend(loc='upper left')
    return mods

# %%
def commonRegressions(df, axes):
    runRegressions(df, [
        ('Population', 'Total', 'CO2 Emissions vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2)', axes[0], 'area'),
        #('Population', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2 per Square Mile)'),
        #('Population', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population', 'log(Population)', 'log(Millions of Tons of CO2 per Capita)', axes[0], 'area'),
        #('area', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Area', 'log(Square Miles)', 'log(Millions of Tons of CO2 per Capita)', ax1),
        ('PopulationDensity', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population Density', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Capita)', axes[1], 'Population'),
        #('PopulationDensity', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population Density by County', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Square Mile)'),
    ])

# %%
fig, (axes) = plt.subplots(figsize=(16,8), nrows=1, ncols=2)
commonRegressions(merged, axes)
# Out:
# CO2 Emissions vs. Population by County
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.675
# Method:                 Least Squares   F-statistic:                     6528.
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):               0.00
# Time:                        14:41:05   Log-Likelihood:                -5151.6
# No. Observations:                3137   AIC:                         1.031e+04
# Df Residuals:                    3135   BIC:                         1.032e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -15.7450      0.161    -97.508      0.000       -16.062   -15.428
# x              0.8755      0.011     80.796      0.000         0.854     0.897
# ==============================================================================
# Omnibus:                     1373.133   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6354.273
# Skew:                           2.118   Prob(JB):                         0.00
# Kurtosis:                       8.538   Cond. No.                         108.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CO2 Emissions per Capita vs. Population Density
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     234.7
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):           3.82e-51
# Time:                        14:41:05   Log-Likelihood:                -5103.1
# No. Observations:                3137   AIC:                         1.021e+04
# Df Residuals:                    3135   BIC:                         1.022e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept    -16.8534      0.052   -321.523      0.000       -16.956   -16.751
# x             -0.1351      0.009    -15.320      0.000        -0.152    -0.118
# ==============================================================================
# Omnibus:                     1408.205   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6803.896
# Skew:                           2.163   Prob(JB):                         0.00
# Kurtosis:                       8.774   Cond. No.                         14.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
filtered = merged[merged.PopulationDensity>1000]
fig, (axes) = plt.subplots(figsize=(16,8), nrows=1, ncols=2)
commonRegressions(filtered, axes)
# Out:
# CO2 Emissions per Capita vs. Population
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     3.373
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):             0.0686
# Time:                        14:09:54   Log-Likelihood:                 11.917
# No. Observations:                 132   AIC:                            -19.83
# Df Residuals:                     130   BIC:                            -14.07
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -5.1707      0.165    -31.350      0.000        -5.497    -4.844
# x             -0.0538      0.029     -1.837      0.069        -0.112     0.004
# ==============================================================================
# Omnibus:                       43.387   Durbin-Watson:                   1.730
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              166.330
# Skew:                           1.110   Prob(JB):                     7.62e-37
# Kurtosis:                       8.031   Cond. No.                         49.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CO2 Emissions per Capita vs. Population Density
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.132
# Model:                            OLS   Adj. R-squared:                  0.125
# Method:                 Least Squares   F-statistic:                     19.69
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):           1.92e-05
# Time:                        14:09:54   Log-Likelihood:                 19.533
# No. Observations:                 132   AIC:                            -35.07
# Df Residuals:                     130   BIC:                            -29.30
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -4.6687      0.182    -25.674      0.000        -5.028    -4.309
# x             -0.2388      0.054     -4.437      0.000        -0.345    -0.132
# ==============================================================================
# Omnibus:                       63.078   Durbin-Watson:                   1.847
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              317.899
# Skew:                           1.601   Prob(JB):                     9.31e-70
# Kurtosis:                       9.895   Cond. No.                         36.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
filtered = merged[merged.Population>1000000]
fig, (axes) = plt.subplots(figsize=(16,8), nrows=1, ncols=2)
commonRegressions(filtered, axes)
#filtered.sort('Population')
# Out:
# CO2 Emissions per Capita vs. Population
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     2.502
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):              0.123
# Time:                        14:13:52   Log-Likelihood:                 9.5423
# No. Observations:                  35   AIC:                            -15.08
# Df Residuals:                      33   BIC:                            -11.97
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -3.9809      0.978     -4.070      0.000        -5.971    -1.991
# x             -0.2472      0.156     -1.582      0.123        -0.565     0.071
# ==============================================================================
# Omnibus:                        1.311   Durbin-Watson:                   1.468
# Prob(Omnibus):                  0.519   Jarque-Bera (JB):                0.488
# Skew:                           0.214   Prob(JB):                        0.784
# Kurtosis:                       3.389   Cond. No.                         196.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CO2 Emissions per Capita vs. Population Density
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.094
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     3.405
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):             0.0740
# Time:                        14:13:52   Log-Likelihood:                 9.9818
# No. Observations:                  35   AIC:                            -15.96
# Df Residuals:                      33   BIC:                            -12.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -5.2057      0.177    -29.411      0.000        -5.566    -4.846
# x             -0.0971      0.053     -1.845      0.074        -0.204     0.010
# ==============================================================================
# Omnibus:                        4.512   Durbin-Watson:                   1.155
# Prob(Omnibus):                  0.105   Jarque-Bera (JB):                3.430
# Skew:                           0.757   Prob(JB):                        0.180
# Kurtosis:                       3.249   Cond. No.                         20.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #MSA STUFF

# %%
msa = pd.read_csv('msa.csv')

# %%
msa.columns
# Out:
# Index([u'CBSA Code', u'Metro Division Code', u'CSA Code', u'CBSA Title',
#        u'Metropolitan/Micropolitan Statistical Area',
#        u'Metropolitan Division Title', u'CSA Title',
#        u'County/County Equivalent', u'State Name', u'FIPS State Code',
#        u'FIPS County Code', u'Central/Outlying County'],
#       dtype='object')

# %%
msa = msa.rename(columns={'CBSA Code': 'MSA', 'Central/Outlying County': 'outlying'})

# %%
msa['FIPS'] = np.core.defchararray.add(np.array([i.zfill(2) for i in msa['FIPS State Code'].astype(int).astype('str')]), np.array([i.zfill(3) for i in msa['FIPS County Code'].astype(int).astype('str')])).astype(int)

# %%
len(msa)
# Out:
# 1882

# %%
msa_merge = pd.merge(msa, merged, on='FIPS')

# %%
len(msa_merge)
# Out:
# 1807

# %%
grouped = msa_merge.groupby('MSA')

# %%
df = pd.DataFrame({
    'Population': grouped.sum()['Population'],
    'Total': grouped.sum()['Total'],
    'area': grouped.sum()['area']
})

df['PopulationDensity'] = grouped.sum()['Population']/grouped.sum()['area']
df['CO2PerCapita'] = grouped.sum()['Total']/grouped.sum()['Population']

# %%
fig, ((ax1, ax2)) = plt.subplots(figsize=(16,8), nrows=1, ncols=2)
runRegressions(df, [
        #('Population', 'Total', 'CO2 Emissions vs. Population by MSA', 'log(Population)', 'log(Millions of Tons of CO2)'),
        #('Population', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2 per Square Mile)'),
        #('Population', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population', 'log(Population)', 'log(Millions of Tons of CO2 per Capita)', ax1),
        ('area', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Area', 'log(Square Miles)', 'log(Millions of Tons of CO2 per Capita)', ax1),
        ('PopulationDensity', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population Density', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Capita)', ax2),
        #('PopulationDensity', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population Density by County', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Square Mile)'),
    ])
# Out:
# CO2 Emissions per Capita vs. Area
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     7.652
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):            0.00579
# Time:                        12:58:15   Log-Likelihood:                -319.12
# No. Observations:                 917   AIC:                             642.2
# Df Residuals:                     915   BIC:                             651.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -5.5568      0.092    -60.304      0.000        -5.738    -5.376
# x              0.0825      0.030      2.766      0.006         0.024     0.141
# ==============================================================================
# Omnibus:                      348.335   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1184.159
# Skew:                           1.862   Prob(JB):                    7.30e-258
# Kurtosis:                       7.138   Cond. No.                         27.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CO2 Emissions per Capita vs. Population Density
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     39.99
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):           3.98e-10
# Time:                        12:58:15   Log-Likelihood:                -303.32
# No. Observations:                 917   AIC:                             610.6
# Df Residuals:                     915   BIC:                             620.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -5.0187      0.046   -108.040      0.000        -5.110    -4.928
# x             -0.1496      0.024     -6.324      0.000        -0.196    -0.103
# ==============================================================================
# Omnibus:                      315.415   Durbin-Watson:                   2.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              949.027
# Skew:                           1.725   Prob(JB):                    8.35e-207
# Kurtosis:                       6.597   Cond. No.                         10.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x33fac400>,
#  <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x33f9d978>]

# %%
filtered = df[df.Population>100000]
fig, ((ax1, ax2)) = plt.subplots(figsize=(16,8), nrows=1, ncols=2)
runRegressions(filtered, [
        #('Population', 'Total', 'CO2 Emissions vs. Population by MSA', 'log(Population)', 'log(Millions of Tons of CO2)'),
        #('Population', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2 per Square Mile)'),
        #('Population', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population', 'log(Population)', 'log(Millions of Tons of CO2 per Capita)', ax1),
        ('area', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Area', 'log(Square Miles)', 'log(Millions of Tons of CO2 per Capita)', ax1),
        ('PopulationDensity', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population Density', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Capita)', ax2),
        #('PopulationDensity', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population Density by County', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Square Mile)'),
    ])
# Out:
# CO2 Emissions per Capita vs. Area
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.810
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):              0.179
# Time:                        12:58:49   Log-Likelihood:                -61.594
# No. Observations:                 366   AIC:                             127.2
# Df Residuals:                     364   BIC:                             135.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -5.5056      0.133    -41.367      0.000        -5.767    -5.244
# x              0.0546      0.041      1.345      0.179        -0.025     0.135
# ==============================================================================
# Omnibus:                       93.194   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              177.791
# Skew:                           1.386   Prob(JB):                     2.47e-39
# Kurtosis:                       4.993   Cond. No.                         31.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CO2 Emissions per Capita vs. Population Density
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     17.72
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):           3.23e-05
# Time:                        12:58:49   Log-Likelihood:                -53.804
# No. Observations:                 366   AIC:                             111.6
# Df Residuals:                     364   BIC:                             119.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -4.9820      0.083    -59.713      0.000        -5.146    -4.818
# x             -0.1549      0.037     -4.209      0.000        -0.227    -0.083
# ==============================================================================
# Omnibus:                       77.566   Durbin-Watson:                   1.910
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              129.958
# Skew:                           1.237   Prob(JB):                     6.03e-29
# Kurtosis:                       4.548   Cond. No.                         15.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x34be84e0>,
#  <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x34be8f60>]

# %%
filtered = df[df.PopulationDensity>83]
fig, ((ax1, ax2)) = plt.subplots(figsize=(16,8), nrows=1, ncols=2)
runRegressions(filtered, [
        #('Population', 'Total', 'CO2 Emissions vs. Population by MSA', 'log(Population)', 'log(Millions of Tons of CO2)'),
        #('Population', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2 per Square Mile)'),
        ('Population', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population', 'log(Population)', 'log(Millions of Tons of CO2 per Capita)', ax1),
        ('PopulationDensity', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population Density', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Capita)', ax2),
        #('PopulationDensity', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population Density by County', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Square Mile)'),
    ])

# %%
woOutlying = msa_merge[msa_merge.outlying=='Central']
grouped = woOutlying.groupby('MSA')

df = pd.DataFrame({
    'Population': grouped.sum()['Population'],
    'Total': grouped.sum()['Total']
})

df['PopulationDensity'] = grouped.sum()['Population']/grouped.sum()['area']
df['CO2PerCapita'] = grouped.sum()['Total']/grouped.sum()['Population']

# %%
fig, ((ax1, ax2)) = plt.subplots(figsize=(16,8), nrows=1, ncols=2)
runRegressions(df, [
        #('Population', 'Total', 'CO2 Emissions vs. Population by MSA', 'log(Population)', 'log(Millions of Tons of CO2)'),
        #('Population', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2 per Square Mile)'),
        ('Population', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2 per Capita)', ax1),
        ('PopulationDensity', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population Density by MSA', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Capita)', ax2),
        #('PopulationDensity', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population Density by County', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Square Mile)'),
    ])
# Out:
# CO2 Emissions per Capita vs. Population by County
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     19.93
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):           9.03e-06
# Time:                        11:48:45   Log-Likelihood:                -298.74
# No. Observations:                 917   AIC:                             601.5
# Df Residuals:                     915   BIC:                             611.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -4.8431      0.107    -45.437      0.000        -5.052    -4.634
# x             -0.0956      0.021     -4.465      0.000        -0.138    -0.054
# ==============================================================================
# Omnibus:                      347.339   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1178.713
# Skew:                           1.857   Prob(JB):                    1.11e-256
# Kurtosis:                       7.131   Cond. No.                         49.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CO2 Emissions per Capita vs. Population Density by MSA
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     38.50
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):           8.29e-10
# Time:                        11:48:45   Log-Likelihood:                -289.73
# No. Observations:                 917   AIC:                             583.5
# Df Residuals:                     915   BIC:                             593.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -5.0487      0.045   -113.405      0.000        -5.136    -4.961
# x             -0.1358      0.022     -6.205      0.000        -0.179    -0.093
# ==============================================================================
# Omnibus:                      334.294   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1103.241
# Skew:                           1.791   Prob(JB):                    2.72e-240
# Kurtosis:                       7.006   Cond. No.                         10.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x2bb05080>,
#  <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x2aba16d8>]

# %%
filtered = df[df.Population>100000]
fig, ((ax1, ax2)) = plt.subplots(figsize=(16,8), nrows=1, ncols=2)
runRegressions(filtered, [
        #('Population', 'Total', 'CO2 Emissions vs. Population by MSA', 'log(Population)', 'log(Millions of Tons of CO2)'),
        #('Population', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2 per Square Mile)'),
        ('Population', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population', 'log(Population)', 'log(Millions of Tons of CO2 per Capita)', ax1),
        ('PopulationDensity', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population Density', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Capita)', ax2),
        #('PopulationDensity', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population Density by County', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Square Mile)'),
    ])
# Out:
# CO2 Emissions per Capita vs. Population
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     9.814
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):            0.00188
# Time:                        11:49:49   Log-Likelihood:                -38.849
# No. Observations:                 345   AIC:                             81.70
# Df Residuals:                     343   BIC:                             89.38
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -4.7805      0.182    -26.200      0.000        -5.139    -4.422
# x             -0.1040      0.033     -3.133      0.002        -0.169    -0.039
# ==============================================================================
# Omnibus:                       85.118   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              161.673
# Skew:                           1.332   Prob(JB):                     7.82e-36
# Kurtosis:                       5.038   Cond. No.                         70.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CO2 Emissions per Capita vs. Population Density
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     14.48
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):           0.000168
# Time:                        11:49:49   Log-Likelihood:                -36.584
# No. Observations:                 345   AIC:                             77.17
# Df Residuals:                     343   BIC:                             84.86
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -5.0319      0.085    -59.255      0.000        -5.199    -4.865
# x             -0.1346      0.035     -3.805      0.000        -0.204    -0.065
# ==============================================================================
# Omnibus:                       77.551   Durbin-Watson:                   1.913
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              137.416
# Skew:                           1.257   Prob(JB):                     1.45e-30
# Kurtosis:                       4.800   Cond. No.                         16.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x2bc649b0>,
#  <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x2bc82cc0>]

# %%
#woOutlying = msa_merge[msa_merge.outlying=='Central']
#grouped = woOutlying.groupby('MSA')

#df = pd.DataFrame({
#    'Population': grouped.sum()['Population'],
#    'Total': grouped.sum()['Total']
#})

#df['PopulationDensity'] = grouped.sum()['Population']/grouped.sum()['area']
#df['CO2PerCapita'] = grouped.sum()['Total']/grouped.sum()['Population']

# %%
#densest = msa_merge[msa_merge.PopulationDensity > 80]
#grouped = densest.groupby('MSA')
pop = []
total = []
area = []
grouped = msa_merge.groupby('MSA')

for name, group in grouped:
    # Get only counties with population >= mean for the MSA
    try:
        f = group[group.PopulationDensity >= group.PopulationDensity.mean()]# + 3*group.Population.std()]
        if len(f) < 1:
            raise Exception
    except:
        f = group[group.PopulationDensity >= group.PopulationDensity.mean()]
    pop.append(f.Population.sum())
    total.append(f.Total.sum())
    area.append(f.area.sum())

#grouped.get_group(47900)[grouped.get_group(47900).Population >= grouped.get_group(47900).Population.mean()]

df = pd.DataFrame({
    'Population': pop,
    'Total': total,
    'area': area
})

df['PopulationDensity'] = df['Population']/df['area']
df['CO2PerCapita'] = df['Total']/df['Population']

# %%
fig, ((ax1, ax2)) = plt.subplots(figsize=(16,8), nrows=1, ncols=2)
runRegressions(df, [
        #('Population', 'Total', 'CO2 Emissions vs. Population by MSA', 'log(Population)', 'log(Millions of Tons of CO2)'),
        #('Population', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2 per Square Mile)'),
        ('Population', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2 per Capita)', ax1),
        ('PopulationDensity', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population Density by MSA', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Capita)', ax2),
        #('PopulationDensity', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population Density by County', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Square Mile)'),
    ])
# Out:
# CO2 Emissions per Capita vs. Population by County
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     33.88
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):           8.11e-09
# Time:                        12:10:27   Log-Likelihood:                -293.58
# No. Observations:                 917   AIC:                             591.2
# Df Residuals:                     915   BIC:                             600.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -4.6822      0.111    -42.153      0.000        -4.900    -4.464
# x             -0.1309      0.022     -5.821      0.000        -0.175    -0.087
# ==============================================================================
# Omnibus:                      364.543   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1326.656
# Skew:                           1.926   Prob(JB):                    8.32e-289
# Kurtosis:                       7.459   Cond. No.                         51.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CO2 Emissions per Capita vs. Population Density by MSA
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     50.66
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):           2.21e-12
# Time:                        12:10:27   Log-Likelihood:                -285.54
# No. Observations:                 917   AIC:                             575.1
# Df Residuals:                     915   BIC:                             584.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -5.0479      0.041   -124.614      0.000        -5.127    -4.968
# x             -0.1374      0.019     -7.118      0.000        -0.175    -0.100
# ==============================================================================
# Omnibus:                      354.868   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1288.923
# Skew:                           1.867   Prob(JB):                    1.30e-280
# Kurtosis:                       7.449   Cond. No.                         9.44
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [<statsmodels.regression.linear_model.RegressionResultsWrapper at 0x30395240>,
#  <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x304e8ac8>]

# %%
filtered = df[df.Population>100000]
fig, ((ax1, ax2)) = plt.subplots(figsize=(16,8), nrows=1, ncols=2)
runRegressions(filtered, [
        #('Population', 'Total', 'CO2 Emissions vs. Population by MSA', 'log(Population)', 'log(Millions of Tons of CO2)'),
        #('Population', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2 per Square Mile)'),
        ('Population', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population', 'log(Population)', 'log(Millions of Tons of CO2 per Capita)', ax1),
        ('PopulationDensity', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population Density', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Capita)', ax2),
        #('PopulationDensity', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population Density by County', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Square Mile)'),
    ])
# Out:
# CO2 Emissions per Capita vs. Population
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     16.68
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):           5.61e-05
# Time:                        12:10:58   Log-Likelihood:                -26.512
# No. Observations:                 320   AIC:                             57.02
# Df Residuals:                     318   BIC:                             64.56
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -4.5514      0.203    -22.445      0.000        -4.950    -4.152
# x             -0.1514      0.037     -4.084      0.000        -0.224    -0.078
# ==============================================================================
# Omnibus:                       87.602   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              180.422
# Skew:                           1.412   Prob(JB):                     6.64e-40
# Kurtosis:                       5.357   Cond. No.                         77.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CO2 Emissions per Capita vs. Population Density
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.063
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     21.21
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):           5.96e-06
# Time:                        12:10:58   Log-Likelihood:                -24.361
# No. Observations:                 320   AIC:                             52.72
# Df Residuals:                     318   BIC:                             60.26
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     -5
# 2779  0.002723          0.000905  3.818007e-04           2.370475
# 83    0.002705          0.000031  3.905591e-04           0.080491
# 3130  0.003861          0.001711  4.103448e-04           4.169924
# 1636  0.003890          0.000834  4.541444e-04           1.836058
# 65    0.004550          0.009549  6.563971e-04          14.547419
# 2013  0.008171          0.005428  6.736669e-04           8.057466
# 2017  0.004934          0.002126  8.007267e-04           2.655075
#
# [3137 rows x 21 columns]

# %%
grouped = msa_merge.groupby('MSA')
df = pd.DataFrame({
    #'MSA': grouped.groups.keys(),
    'MSA': [g.iloc[0]['CBSA Title'] for _,g in grouped],
    'Population': grouped.sum()['Population'],
    'Total': grouped.sum()['Total']
})

df['PopulationDensity'] = grouped.sum()['Population']/grouped.sum()['area']
df['CO2PerCapita'] = grouped.sum()['Total']/grouped.sum()['Population']

# %%
df[df.Population > 500000].sort('CO2PerCapita')
# Out:
#                                                   MSA  Population      Total  \
# MSA
# 31080              Los Angeles-Long Beach-Anaheim, CA    12634977  26.645275
# 23420                                      Fresno, CA      828245   1.785504
# 32580                    McAllen-Edinburg-Mission, TX      607449   1.438398
# 35620           New York-Newark-Jersey City, NY-NJ-PA    19232075  45.614558
# 38060                     Phoenix-Mesa-Scottsdale, AZ     3496957   8.441516
# 21340                                     El Paso, TX      692083   1.671084
# 39580                                     Raleigh, NC      863488   2.100678
# 41940              San Jose-Sunnyvale-Santa Clara, CA     1728245   4.220193
# 33100       Miami-Fort Lauderdale-West Palm Beach, FL     5212602  12.734297
# 38900             Portland-Vancouver-Hillsboro, OR-WA     2010666   4.982120
# 46060                                      Tucson, AZ      886063   2.195879
# 44700                               Stockton-Lodi, CA      608367   1.526506
# 42660                     Seattle-Tacoma-Bellevue, WA     3121895   7.973715
# 41740                          San Diego-Carlsbad, CA     2901235   7.446142
# 40140            Riverside-San Bernardino-Ontario, CA     3483348   9.412956
# 40900         Sacramento--Roseville--Arden-Arcade, CA     1921903   5.311139
# 25540        Hartford-West Hartford-East Hartford, CT     1165667   3.257170
# 18140                                    Columbus, OH     1722310   4.925279
# 35300                           New Haven-Milford, CT      832376   2.383268
# 37100                Oxnard-Thousand Oaks-Ventura, CA      776560   2.237313
# 10420                                       Akron, OH      699606   2.048257
# 42540            Scranton--Wilkes-Barre--Hazleton, PA      552490   1.619074
# 41860               San Francisco-Oakland-Hayward, CA     4165678  12.327485
# 45060                                    Syracuse, NY      648854   1.921924
# 41620                              Salt Lake City, UT      970111   2.885457
# 10740                                 Albuquerque, NM      753670   2.265461
# 24660                       Greensboro-High Point, NC      656811   1.997534
# 37980     Philadelphia-Camden-Wilmington, PA-NJ-DE-MD     5755874  17.528782
# 19100                 Dallas-Fort Worth-Arlington, TX     5521873  16.895415
# 30780        Little Rock-North Little Rock-Conway, AR      623045   1.936453
# ...                                               ...         ...        ...
# 34980  Nashville-Davidson--Murfreesboro--Franklin, TN     1435099   6.604361
# 45300             Tampa-St. Petersburg-Clearwater, FL     2483575  11.731247
# 41700                   San Antonio-New Braunfels, TX     1777397   8.864799
# 17900                                    Columbia, SC      663454   3.431951
# 17140         487.538365      0.000007
# 12540          84.658812      0.000007
# 41180         343.506945      0.000007
# 33460         406.295889      0.000008
# 17460        1067.921234      0.000008
# 35380         391.965583      0.000008
# 31140         316.375543      0.000008
# 46140         139.281791      0.000008
# 28940         218.817903      0.000009
# 49180         290.805334      0.000009
# 16700         218.661423      0.000010
# 13820         201.034534      0.000013
# 10900         518.251711      0.000015
# 12940         177.065053      0.000026
#
# [93 rows x 5 columns]

# %%
mod = smf.ols(formula='log(CO2PerCapita) ~ log(area) + log(PopulationDensity)', data = merged).fit()
#mods.append(mod)
print mod.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      log(CO2PerCapita)   R-squared:                       0.072
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     121.1
# Date:                Sun, 15 Nov 2015   Prob (F-statistic):           2.22e-51
# Time:                        13:32:47   Log-Likelihood:                -3949.8
# No. Observations:                3137   AIC:                             7906.
# Df Residuals:                    3134   BIC:                             7924.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Intercept                -12.0915      0.159    -76.108      0.000       -12.403   -11.780
# log(area)                  0.0539      0.020      2.649      0.008         0.014     0.094
# log(PopulationDensity)    -0.1192      0.011    -11.165      0.000        -0.140    -0.098
# ==============================================================================
# Omnibus:                     1419.857   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6986.000
# Skew:                           2.176   Prob(JB):                         0.00
# Kurtosis:                       8.874   Cond. No.                         80.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
-16.8534      0.052   -321.523      0.000       -16.956   -16.751
x             -0.1351
-15.7450      0.161    -97.508      0.000       -16.062   -15.428
x              0.8755
    runRegressions(df, [
        ('Population', 'Total', 'CO2 Emissions vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2)', axes[0], 'area'),
        #('Population', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population by County', 'log(Population)', 'log(Millions of Tons of CO2 per Square Mile)'),
        #('Population', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population', 'log(Population)', 'log(Millions of Tons of CO2 per Capita)', axes[0], 'area'),
        #('area', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Area', 'log(Square Miles)', 'log(Millions of Tons of CO2 per Capita)', ax1),
        ('PopulationDensity', 'CO2PerCapita', 'CO2 Emissions per Capita vs. Population Density', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Capita)', axes[1], 'Population'),
        #('PopulationDensity', 'CO2PerSquareMile', 'CO2 Emissions per Square Mile vs. Population Density by County', 'log(Population per Square Mile)', 'log(Millions of Tons of CO2 per Square Mile)'),
    ])

# %%
fig, ((ax1, ax2)) = plt.subplots(figsize=(16,16), nrows=2, ncols=1)

# Pop vs Total
x = np.logspace(5,27,100,base=2)
y = 2**((np.log2(x)*.8755) + (-15.7450))
ax1.plot(x,y, label='County')
ax1.set_title('Predicted Growth of Total Emissions as Population Increases')
ax1.set_ylabel('Millions of Tons of CO2')
ax1.set_xlabel('Population')
ax1.legend(loc='upper left')

x = np.logspace(0,16,100,base=2)
y = 2**((np.log2(x)*-.1351) + (-16.8534))
ax2.plot(x,y, label='County')
ax2.set_title('Predicted Decrease of Emissions per Capita as Population Density Increases')
ax2.set_ylabel('Millions of Tons of CO2 per Capita')
ax2.set_xlabel('Population per Square Mile')
ax2.legend(loc='upper left')
ax2.set_xlim([-1000,2**16])
# Out:
# (-1000, 65536)

# %%
np.logspace(0,20,100,base=2)
# Out:
# array([  1.00000000e+00,   1.15030800e+00,   1.32320850e+00,
